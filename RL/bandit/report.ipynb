# %% [markdown]
# ## Artificial Intelligence - Methods and Applications - 5DV181
#
# ### Assignment 2 - Reinforcement learning
#
# #### Elias Niko -                                    c18eno@cs.umu.se
# #### Mojtaba Mabizada -                              c18mna@cs.umu.se
